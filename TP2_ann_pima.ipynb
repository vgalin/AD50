# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os

# %%
# Load data
file_path = os.path.join('input', 'diabetes.csv')
dataset = pd.read_csv(file_path)

dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
features = [
    'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
    'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'
]
X = dataset[features]
y = dataset.Outcome

# %%
# Split data into training and validation data, for both features and target.
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size = 0.2, random_state = 0)

# apply feature scaling
sc = StandardScaler()
train_X = sc.fit_transform(train_X)
val_X = sc.transform(val_X)

# %%
model = Sequential()

# Adding the input layer and the first hidden layer
#        the second hidden layer
#        the output layer
# + compile ("Configures the model for training")
model.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 8))
model.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
# model.fit(train_X, train_y, batch_size=10, epochs=100)
model.fit(train_X, train_y, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.6401
# Epoch 2/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6591 - accuracy: 0.6401
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.6401
# Epoch 4/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5458 - accuracy: 0.6401
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5328 - accuracy: 0.6401
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.6401
# Epoch 7/100
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5227 - accuracy: 0.6401
# Epoch 8/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7410
# Epoch 9/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5174 - accuracy: 0.7638
# Epoch 10/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.7720
# Epoch 11/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.7769
# Epoch 12/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7785
# Epoch 13/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5090 - accuracy: 0.7736
# Epoch 14/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.7736
# Epoch 15/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.7769
# Epoch 16/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7801
# Epoch 17/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7769
# Epoch 18/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7785
# Epoch 19/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5013 - accuracy: 0.7801
# Epoch 20/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7769
# Epoch 21/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7818
# Epoch 22/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4989 - accuracy: 0.7785
# Epoch 23/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4971 - accuracy: 0.7769
# Epoch 24/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.7785
# Epoch 25/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4964 - accuracy: 0.7720
# Epoch 26/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4956 - accuracy: 0.7785
# Epoch 27/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.7590
# Epoch 28/100
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4934 - accuracy: 0.7736
# Epoch 29/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.7736
# Epoch 30/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4920 - accuracy: 0.7638
# Epoch 31/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4914 - accuracy: 0.7622
# Epoch 32/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4905 - accuracy: 0.7801
# Epoch 33/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7818
# Epoch 34/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4895 - accuracy: 0.7769
# Epoch 35/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.7671
# Epoch 36/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7671
# Epoch 37/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7801
# Epoch 38/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.7622
# Epoch 39/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.7752
# Epoch 40/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.7769
# Epoch 41/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.7785
# Epoch 42/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.7785
# Epoch 43/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4850 - accuracy: 0.7801
# Epoch 44/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4842 - accuracy: 0.7834
# Epoch 45/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.7752
# Epoch 46/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.7801
# Epoch 47/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7785
# Epoch 48/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7736
# Epoch 49/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4826 - accuracy: 0.7818
# Epoch 50/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4824 - accuracy: 0.7818
# Epoch 51/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4815 - accuracy: 0.7850
# Epoch 52/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4813 - accuracy: 0.7785
# Epoch 53/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7736
# Epoch 54/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7834
# Epoch 55/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4799 - accuracy: 0.7801
# Epoch 56/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4790 - accuracy: 0.7801
# Epoch 57/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.7801
# Epoch 58/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.7801
# Epoch 59/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.7834
# Epoch 60/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4775 - accuracy: 0.7785
# Epoch 61/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.7801
# Epoch 62/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4770 - accuracy: 0.7785
# Epoch 63/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4763 - accuracy: 0.7736
# Epoch 64/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.7785
# Epoch 65/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7785
# Epoch 66/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4752 - accuracy: 0.7818
# Epoch 67/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4746 - accuracy: 0.7801
# Epoch 68/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7801
# Epoch 69/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.7818
# Epoch 70/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4738 - accuracy: 0.7818
# Epoch 71/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.7818
# Epoch 72/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4726 - accuracy: 0.7785
# Epoch 73/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4718 - accuracy: 0.7801
# Epoch 74/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4712 - accuracy: 0.7801
# Epoch 75/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4711 - accuracy: 0.7850
# Epoch 76/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7769
# Epoch 77/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.7818
# Epoch 78/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7785
# Epoch 79/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.7801
# Epoch 80/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.7834
# Epoch 81/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.7785
# Epoch 82/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.7866
# Epoch 83/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4675 - accuracy: 0.7834
# Epoch 84/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7850
# Epoch 85/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4669 - accuracy: 0.7850
# Epoch 86/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.7834
# Epoch 87/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4661 - accuracy: 0.7866
# Epoch 88/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7834
# Epoch 89/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.7883
# Epoch 90/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7834
# Epoch 91/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7850
# Epoch 92/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.7866
# Epoch 93/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.7834
# Epoch 94/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4639 - accuracy: 0.7866
# Epoch 95/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.7834
# Epoch 96/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.7850
# Epoch 97/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4626 - accuracy: 0.7834
# Epoch 98/100
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4624 - accuracy: 0.7866
# Epoch 99/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4622 - accuracy: 0.7850
# Epoch 100/100
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4617 - accuracy: 0.7866

# %%
# Predicting the Test set results
val_predictions = model.predict(val_X)
val_predictions = (val_predictions > 0.5) # transform float to bool

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(val_y, val_predictions)

print(cm)

val_mae = mean_absolute_error(val_y, val_predictions)
print(f'mean_absolute_error = {val_mae}')
# Out:
# [[94 13]
#  [18 29]]
# mean_absolute_error = 0.2012987012987013
